# %% [markdown]
# ### Reinforcemeant Learning

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2-2.png](attachment:2-2.png)

# %% [markdown]
# ![Reiforcement_Learning_Taxi.png](attachment:Reiforcement_Learning_Taxi.png)
